# %% [markdown]
# <a href="https://colab.research.google.com/github/riju-t-r/ML-AI/blob/master/Intro_TF%2CDP%2CAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Installing TF 2.3.0 in Colabs Google
#
# ```pip install tensorflow==2.3.0```

# %%
# !pip install tensorflow==2.3.0
# Out:
# ...
#      |████████████████████████████████| 320.4MB 33kB/s
# ...
#   Found existing installation: tensorflow 2.0.0a0
#     Uninstalling tensorflow-2.0.0a0:
#       Successfully uninstalled tensorflow-2.0.0a0
# ...

# %%
import tensorflow as tf
import keras 
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
xs = np.array([-1.0,0.0,1.0,2.0,3.0,4.0], dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0], dtype=float)

# %%
model.fit(xs,ys, epochs=800)
# Out:
# Epoch 1/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.4550e-05
# Epoch 2/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3840e-05
# Epoch 3/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.3145e-05
# Epoch 4/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.2464e-05
# Epoch 5/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1798e-05
# Epoch 6/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.1144e-05
# Epoch 7/800
# 1/1 [==============================] - 0s 2ms/step - loss: 3.0505e-05
# Epoch 8/800
# 1/1 [==============================] - 0s 2ms/step - loss: 2.9878e-05
# Epoch 9/800
# 1/1 [==============================] - 0s 3ms/step - loss: 2.9266e-05
# Epoch 10/800
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8665e-05
# Epoch 11/800
# 1/1 [==============================] - 0s 3ms/step - loss: 2.8076e-05
# Epoch 12/800
# ...

# %%
print(model.predict([10.0]))
# Out:
# [[18.999987]]
